# %%
import pandas as pd

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu

# %%
def matrix_cosine(merge_coll, top=200):
    from scipy.spatial.distance import cosine

    stack = []
    res = dict()
    for i in merge_coll:
        res[i] = dict()
        for j in merge_coll:
            res[i][j] = 1 - cosine(merge_coll[i][:top].fillna(0), merge_coll[j][:top].fillna(0))  

    return res

# %% [markdown]
# Henter ut referansematerialet

# %%
tot = nb.frame(nb.totals(50000), 'tot')

# %% [markdown]
# Finner et korpus over Frodo

# %%
harry = nb.book_urn(author="%tolkien%", title="%", limit=100)

# %% [markdown]
# Sjekker at URNene er unike

# %%
harry = nb.unique_urns(harry)

# %%
nb.frame(nb.metadata(nb.pure_urn(harry)))
# Out:
#                 0                1     2  \
# 0   2008082200016  Tolkien, J.R.R.  1998
# 1   2008030504070  Tolkien, J.R.R.  1995
# 2   2008121500142  Tolkien, J.R.R.  1997
# 3   2014030308443  Tolkien, J.R.R.  2004
# 4   2014120408017  Tolkien, J.R.R.  2008
# 5   2008091600054  Tolkien, J.R.R.  1998
# 6   2016072808055  Tolkien, J.R.R.  2004
# 7   2015092548015  Tolkien, J.R.R.  2008
# 8   2013071208011  Tolkien, J.R.R.  2012
# 9   2014021806024  Tolkien, J.R.R.  2008
# 10  2010051003054  Tolkien, J.R.R.  1995
# 11  2014093008042  Tolkien, J.R.R.  1975
# 12  2012082208227  Tolkien, J.R.R.  1994
# 13  2010062508054  Tolkien, J.R.R.  1999
#
#                                          3                      4  \
# 0                             Silmarillion
# 1                           Trær og blader
# 2                      Brev fra julenissen
# 3                  Ufullendte fortellinger  om Númenor og Midgard
# 4         Hobbiten, eller Ditut og attende
# 5   Hobbiten , eller Fram og tilbake igjen
# 6                           Ringenes herre
# 7                               Herr Lykke
# 8    Hobbiten, eller Fram og tilbake igjen
# 9                              Ringdrotten
# 10            Volund smed fra store Skauby
# 11                        Krigen om ringen
# 12                    Eigil Bonde fra Heim
# 13                             Rundtomrask
#
#                                     5            6  \
# 0                               Tiden      fiction
# 1                               Tiden   notfiction
# 2                               Tiden      fiction
# 3                               Tiden  short story
# 4                               Tiden        novel
# 5                               Tiden        novel
# 6    Tiden;[Oslo] : Tiden, 2004-    .      fiction
# 7                               Tiden        novel
# 8                               Tiden        novel
# 9                               Tiden        novel
# 10                              Tiden      fiction
# 11  Tiden;[Oslo] : Tiden, c1973-1975.      unknown
# 12                              Tiden      fiction
# 13                              Tiden      fiction
#
#                                    7    8    9
# 0   cbf34aaa0c6f55ca8daf785c78eb1298  nob  eng
# 1   5dd912bd47f6ded0884c7ce2a1b72d0d  nob  eng
# 2   6c6539ae4947cfec30a60700c4455e7a  nob  eng
# 3   e0ed68c459e2a5978f1c33b869da7111  nob  eng
# 4   49c9903c81099a51e8e49f9afbf3e950  nno  eng
# 5   527e066d38f561c0df01c89145edb283  nob  eng
# 6   631129232c6ab1bca171d0c3f04bb02f  nob
# 7   4f603660aa93efbd16e121d7061f53b3  mul  eng
# 8   6658e52f440fa1efa1ad7b53cd9e89c2  nob  eng
# 9   717d4cfb36eab46bfecf710519fd58e2  nno  eng
# 10  4c619f06a8648ad76639ac81ca52f9fc  nob  eng
# 11  492d02ab79b1ea5f244070da0cf611f0  nob
# 12  ff0604a06b5dbf30b5a8c00c5fc28031  nob  eng
# 13  b3c53dbe4f9733498b0c0156e84931b5  nob  eng

# %% [markdown]
# Ser ut som alt ligger i siste bok, som inneholder hele serien. Men bør sjekke om alt er der. For øyblikket får det holde.

# %%
whole_series = [2016072808055,2013071208011]

# %%
whole_freq = nb.aggregate_urns(whole_series)

# %%
korpus_freq = nb.frame(whole_freq, 'korpus')

# %%
tot_korp = pd.concat([tot, nb.frame(whole_freq)], axis=1, sort=False).fillna(0)

# %%
tot_korp.loc['Frodo']
# Out:
# tot    32539.0
# 0       1073.0
# Name: Frodo, dtype: float64

# %%
total = nb.frame(tot_korp.fillna(0).mean(axis=1), 'tot')

# %%
total.loc['Frodo']
# Out:
# tot    16806.0
# Name: Frodo, dtype: float64

# %%
characters = "Frodo Bilbo Legolas Elron Gandalv".split()

# %%
coll = dict()
for word in characters:
    coll[word] = nb.urn_coll(word, whole_series,after=3, before=0)

# %%
for w in coll:
    if not coll[w].empty:
        coll[w].columns = [w]

# %%
coll_matrix = pd.concat([coll[w] for w in coll], axis=1, sort=False)

# %%
coll_matrix.head()
# Out:
#      Frodo  Bilbo  Legolas  Gandalv
# .    352.0  161.0     33.0    231.0
# «    268.0  105.0     29.0    193.0
# ,    163.0  131.0     16.0    105.0
# og   133.0  100.0     14.0     73.0
# Jeg   52.0    9.0      3.0     23.0

# %%
sky = nb.frame_sort(nb.frame(coll_matrix['Gandalv']/tot['tot'])).head(20)
nb.cloud(sky)

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def character_words(Character_name, number_of_words=50):
    result = {}
    try:
        res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
        result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    except:
        print("problemer med ", Character_name)
    return result

# %%
select_form('rødt')
# Out:
# 'subst'

# %%
nb.word_form('spiste')
# Out:
# ['adj <perf-part> be ent <intrans1> <trans1> <trans11/opp> <trans11/på> <predik6> <refl9/innpå> <trans4> <part3/i> normert',
#  'adj <perf-part> fl <intrans1> <trans1> <trans11/opp> <trans11/på> <predik6> <refl9/innpå> <trans4> <part3/i> normert',
#  'verb pret <intrans1> <trans1> <trans11/opp> <trans11/på> <predik6> <refl9/innpå> <trans4> <part3/i> normert']

# %%
nb.word_lemma('spiste')
# Out:
# [['adj', 'spise'], ['verb', 'spise']]

# %%
character_words('Frodo')
# Out:
# {'verb': ['gjengjeldte',
#   'overhørte',
#   'galopperte',
#   'måpte',
#   'seglet',
#   'forhørte',
#   'krabbet',
#   'overmannet',
#   'forbløffet',
#   'innhyllet',
#   'berøvet',
#   'adlød',
#   'skjermet',
#   'ergret',
#   'spekulere',
#   'gjettet',
#   'skottet',
#   'nikk',
#   'gjenkjente',
#   'bukket',
#   'gispet'],
#  'adj': ['buskete',
#   'rastløs',
#   'unnvikende',
#   'granskende',
#   'oppmerksomt',
#   'utydelig',
#   'tvilende'],
#  'subst': ['dverg',
#   'kraftanstrengelse',
#   'vemmelse',
#   'kjølen',
#   'arvingen',
#   'forbifarten',
#   'rytteren',
#   'hårene',
#   'visitt',
#   'ærefrykt',
#   'søvnen',
#   'taus'],
#  'unknown': ['skjelving', 'sammen,']}

# %%
cw = dict()
for w in characters:
    cw[w] = character_words(w, number_of_words=150)
# Out:
# problemer med  Elron

# %%
text = ""
for ch in cw:
    #print(ch)
    innertext = ""
    for cat in cw[ch]:
        words = ', '.join([w for w in cw[ch][cat]])
        innertext += "\n## " + cat + "\n" + words
    #print(ch, words)
    text += "\n# "+ ch + "\n" + innertext
mu.printmd(text)
# Out:
# # Frodo
#
# ## verb
# gjengjeldte, overhørte, galopperte, måpte, seglet, forhørte, krabbet, overmannet, forbløffet, innhyllet, berøvet, adlød, skjermet, ergret, spekulere, gjettet, skottet, nikk, gjenkjente, bukket, gispet, skalv, oppslukt, grøsset, streker, spalte, trampet, merket, surret, henrykt, kjekk, smatt, utbrøt, bedrøvet, overlot, vekket, tømte, pustet, vinket, vandret, gransket, konsentrerte, skjelne, spente, tilbød, fryd, våknet, beskrev, lyttet, kjentes, stirret, kledde, rørt, syntes, spratt, turer, låste, rørte, snakka, skikk, gjemte, spiste, steget, kikket, svelget, fryktet
# ## adj
# buskete, rastløs, unnvikende, granskende, oppmerksomt, utydelig, tvilende, søvnig, spørrende, engstelig, ergerlig, dystre, dødelig, takknemlig, nølende, stivt, smilende, skarpt, boende, glødende, seige
# ## subst
# dverg, kraftanstrengelse, vemmelse, kjølen, arvingen, forbifarten, rytteren, hårene, visitt, ærefrykt, søvnen, taus, frokosten, fødselsdag, skikken, kompani, hemmeligheten, humøret, vogna, lysten, smertene, konvolutten, skikkelser, dråper, kameratene, kulden, beltet, stien, herren, sverdet, smerten, ungen, nyheter, åpning
# ## unknown
# skjelving, sammen,, såtte
# ## adv
# tidsnok
# ## prep
# utenpå, forover
# # Bilbo
#
# ## verb
# unnslapp, spiddet, plystre, tilsto, saktnet, fordra, plasket, spisset, klasket, avskydde, overhørte, pilte, dinglet, heist, sluppet, travet, slep, gjettet, foretrukket, bukk, ølet, sverget, forestilt, snappet, ramlet, mynter, stønn, karet, klatre, ram, knelte, påtatt, spesialisert, rygget, kremtet, påsto, hakk, marsjerte, etterlatt, snek, forferdet, skottet, strevde, fortapt, forbløffet, hengte, danset, fristet, stammet, stormet, forbannet, glemte, rødmet, bukket, gjette, forstod, blunket, bleke, slappe, minnes, dyttet, håpe, styrtet, undret, rund, krøp, nølte, stanset
# ## adj
# rastløst, skarpeste, hjertens, makelig, iltert, avskyelige, nedslått, storslagne, unnskyldende, utålmodig, bakerst, tilbøyelig, tåpelige, atskillige, søvnig, taust, svimmel, magiske, vidunderlige, pinlig, høytidelig, ulykkelig, forferdelig, høflig, hengende, stivt, lukkede, travelt
# ## subst
# busken, trollmannen, beklagelse, forargelse, medynk, ringen, krakken, kanin, kakene, undring, knappene, dragen, hastverk, vennskapet, ryktene, tosk, historiene, konvolutten, latteren, sete, sverdet, suiten, bredden, steinen, hemmelighet, anelse
# ## unknown
# forbløffelse, arbeidsværelset, bakfrå, søvne
# ## adv
# gladelig, synderlig, heldigvis
# ## prep
# attpå
# # Legolas
#
# ## verb
# bedrøvet, klatre, trass, bue, rørte, skjøt, nærmet, latt, fyr, løp, presset, passe, fortsette, slapp, sang, lette, svarer, snudde, fortalte, fortsatte, deler, døde, ga, sagt, lett, kommet, spurte, lå, visste, sto, frem, gikk, komme, opp, sitt, tok, kom, min, la, dem, så, seg, hadde, men, skulle, ble, sa, være, var, vil, skal, to, eller, for, en, er
# ## subst
# historier, taket, hjerte, resten, hand, mens, med, ham, om, hun, i
# ## adj
# skarpe, villig, sittende, sint, yngre, mye
# ## adv
# straks, hvorfor, sammen, igjen
# ## sbu
# idet, som
# ## prep
# borte, blant, bort, tilbake, gjennom, ned, her, inn, etter, på, der, fra, til
# ## det
# eget, noen, hans
# ## pron
# hva, han, de, det, den
# ## CLB
# og
# ## fork
# av
# # Elron
#
# # Gandalv
#
# ## adj
# bistert, tyngst, barskt, faretruende, mistenkelig, farende, motvillig, høytidelig, stivt, lukkede, uventet, smilende, vennlig, kortere, endelig, underlig, sittende, plutselig, sint
# ## unknown
# utbrot, såtte
# ## subst
# staven, villspor, trollmannen, dverg, forsetet, uråd, fortellingen, skyggene, onsdag, avskjed, innerst, inngående, verst, dører, våken, farvel, vennene, taus, enden, pause, overhodet, farten, fjell, trappen, brevet, stolen, hesten
# ## verb
# unte, spottet, unnslapp, plystret, forvandler, overhørte, hikket, hyl, mintes, snuste, tidde, rukket, forbløffet, lagd, skynde, bukket, forsinket, listet, savner, leide, gledet, forklart, vinner, innstilt, bød, vekket, savnet, trådte, red, skjønt, utbrøt, vendt, fortalt, rakk, husket, røre, sprang, hvisket, glemte, revet, løpe, farger, ristet, løfte, rakte, forstod, brøt, forlot, sagt, lo, førte, bortsett, løftet, pleide, valgt, åpenbart, snakk, vokste, sov, håpet, mumlet, pekte, dukket, falt, betraktet, sikte, fanget, stirret, talte
# ## adv
# muligens
# ## sbu
# ettersom, idet
# ## symb
# dl

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Harry']/tot['tot'], 'association')).head(20).index))
# Out:
# ['Ronny', 'Hermine', 'Potter', 'kjensel', 'bråsnudde', 'glodde', 'måpte', 'Harry', 'overhørte', 'glante', 'indignert', 'Assen', 'målløs', 'pot', 'Perry', 'bøy', 'bistert', 'gapte', 'fortumlet', 'myste']

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Hermine']/tot['tot'], 'association')).head(20).index))
# Out:
# ['Ronny', 'Hermine', 'spisst', 'barskt', 'beklemt', 'Harry', 'skingrende', 'indignert', 'oppspilt', 'overhørte', 'bistert', 'skottet', 'nervøst', 'lyserød', 'øyebrynene', 'forskende', 'vekslet', 'godnatt', 'bestyrtet', 'bommen']

# %%
res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix['Ronny']/tot['tot'], 'association')).head(50).index))['other']}
result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ronny'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-3f4306c6a17c> in <module>
# ----> 1 res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix['Ronny']/tot['tot'], 'association')).head(50).index))['other']}
#       2 result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
#       3 print(result)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ronny'

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Malfang']/tot['tot'], 'association')).head(20).index))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Malfang'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-1e03d509c8ab> in <module>
# ----> 1 print(list(nb.frame_sort(nb.frame(coll_matrix['Malfang']/tot['tot'], 'association')).head(20).index))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Malfang'

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Humlesnurr']/tot['tot'], 'association')).head(20).index))

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Slur']/tot['tot'], 'association')).head(20).index))

# %%
merge_coll = pd.concat([nb.frame(coll_matrix[w]/tot['tot'], w) for w in coll_matrix], axis=1, sort=False)

# %%
merge_coll.head()
# Out:
#           Frodo         Bilbo  Legolas       Gandalv
# !  9.373616e-07  2.454995e-07      NaN  4.017264e-07
# "           NaN           NaN      NaN           NaN
# #           NaN           NaN      NaN           NaN
# $           NaN           NaN      NaN           NaN
# %           NaN           NaN      NaN           NaN

# %%
nb.heatmap(nb.frame(merge_coll.loc["syk dårlig føler følte sa sier mente mener hevdet hevder løy ond ondskapsfullt".split()]))
# Out:
# <style  type="text/css" >
#     #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row3_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row3_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row3_col3 {
#             background-color:  #229322;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row4_col0 {
#             background-color:  #68ba68;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row4_col1 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row4_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row4_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row5_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row5_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row6_col1 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row6_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row6_col3 {
#             background-color:  #198e19;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row7_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row7_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row7_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row7_col3 {
#             background-color:  #63b763;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row8_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row8_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row9_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row9_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row9_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row10_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row10_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row10_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row10_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row11_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row11_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row11_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row11_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row12_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row12_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row12_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row12_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_4965483a_ec24_11e9_b65f_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Frodo</th>        <th class="col_heading level0 col1" >Bilbo</th>        <th class="col_heading level0 col2" >Legolas</th>        <th class="col_heading level0 col3" >Gandalv</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4965483a_ec24_11e9_b65f_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >syk</th>
#                         <td id="T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_4965483a_ec24_11e9_b65f_a0a4c554f2a3row0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_4965483a_ec24_11e9_b

# %%
nb.heatmap(nb.frame_sort(merge_coll, 'Harry')[:20])
# Out:
# <style  type="text/css" >
#     #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row1_col0 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row1_col1 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row1_col3 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row2_col0 {
#             background-color:  #c5edc5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row3_col0 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row3_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row3_col3 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row4_col0 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row4_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row4_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row5_col0 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row5_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row5_col3 {
#             background-color:  #9cd69c;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row6_col0 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row6_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row6_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row7_col0 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row7_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row7_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row7_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row8_col0 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row8_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row8_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row9_col0 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row9_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row9_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row9_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row10_col0 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row10_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row10_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row10_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row11_col0 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row11_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row11_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row11_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row12_col0 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row12_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row12_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row12_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row13_col0 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row13_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row13_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row13_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row14_col0 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row14_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row14_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4970b6e2_ec24_11e9_8701_a0a4c554f2a3row14_col3 {
#             background-color:  #e5ffe5;

# %%
cosinus = nb.frame(matrix_cosine(merge_coll, top=300))

# %%
nb.heatmap(nb.frame_sort(cosinus, 'Frodo'))
# Out:
# <style  type="text/css" >
#     #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row0_col1 {
#             background-color:  #188d18;
#             color:  #000000;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row0_col3 {
#             background-color:  #068306;
#             color:  #f1f1f1;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row1_col0 {
#             background-color:  #058305;
#             color:  #f1f1f1;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row1_col1 {
#             background-color:  #128a12;
#             color:  #f1f1f1;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row1_col2 {
#             background-color:  #b5e4b5;
#             color:  #000000;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row1_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row2_col0 {
#             background-color:  #168c16;
#             color:  #000000;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row2_col2 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row2_col3 {
#             background-color:  #158b15;
#             color:  #000000;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row3_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row3_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Frodo</th>        <th class="col_heading level0 col1" >Bilbo</th>        <th class="col_heading level0 col2" >Legolas</th>        <th class="col_heading level0 col3" >Gandalv</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >Frodo</th>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row0_col1" class="data row0 col1" >0.920551</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row0_col2" class="data row0 col2" >0.181809</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row0_col3" class="data row0 col3" >0.980386</td>
#             </tr>
#             <tr>
#                         <th id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3level0_row1" class="row_heading level0 row1" >Gandalv</th>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row1_col0" class="data row1 col0" >0.980386</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row1_col1" class="data row1 col1" >0.940767</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row1_col2" class="data row1 col2" >0.355098</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row1_col3" class="data row1 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3level0_row2" class="row_heading level0 row2" >Bilbo</th>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row2_col0" class="data row2 col0" >0.920551</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row2_col1" class="data row2 col1" >1</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row2_col2" class="data row2 col2" >0.251672</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row2_col3" class="data row2 col3" >0.940767</td>
#             </tr>
#             <tr>
#                         <th id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3level0_row3" class="row_heading level0 row3" >Legolas</th>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row3_col0" class="data row3 col0" >0.181809</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row3_col1" class="data row3 col1" >0.251672</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row3_col2" class="data row3 col2" >1</td>
#                         <td id="T_5350bf3a_ec24_11e9_bb99_a0a4c554f2a3row3_col3" class="data row3 col3" >0.355098</td>
#             </tr>
#     </tbody></table>

# %%
import networkx as nx

# %%
import dhlab.graph_networkx_louvain as gnl

# %%
G = nx.from_pandas_adjacency(cosinus)

# %%
gnl.show_graph(G)
# Out:
# C:\Users\larsj\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
gnl.show_communities(G)
# Out:
# Bilbo :  Bilbo
#
# Frodo :  Frodo
#
# Gandalv :  Gandalv
#
# Legolas :  Legolas

# %%
nb.urn_concordance(word = "fortumlet", urns = whole_series, size=20)
