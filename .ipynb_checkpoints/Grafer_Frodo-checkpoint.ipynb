# %%
import pandas as pd

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu

# %%
def matrix_cosine(merge_coll, top=200):
    from scipy.spatial.distance import cosine

    stack = []
    res = dict()
    for i in merge_coll:
        res[i] = dict()
        for j in merge_coll:
            res[i][j] = 1 - cosine(merge_coll[i][:top].fillna(0), merge_coll[j][:top].fillna(0))  

    return res

# %% [markdown]
# Henter ut referansematerialet

# %%
tot = nb.frame(nb.totals(50000), 'tot')

# %% [markdown]
# Finner et korpus over Harry Potter

# %%
harry = nb.book_urn(author="%rowling%", title="%potter%", limit=100)

# %% [markdown]
# Sjekker at URNene er unike

# %%
harry = nb.unique_urns(harry)

# %%
nb.frame(nb.metadata(nb.pure_urn(harry)))
# Out:
#                0              1     2                                   3  \
# 0  2014022806023  Rowling, J.K.  2011      Harry Potter og de vises stein
# 1  2013072208063  Rowling, J.K.  2011  Harry Potter og fangen fra Azkaban
# 2  2014080508046  Rowling, J.K.  2001                    Harry Potter 1-4
# 3  2014073005084  Rowling, J.K.  2011          Harry Potter og ildbegeret
# 4  2014022605057  Rowling, J.K.  2011    Harry Potter og halvblodsprinsen
# 5  2014030406051  Rowling, J.K.  2011    Harry Potter og mysteriekammeret
# 6  2012112638152  Rowling, J.K.  2011     Harry Potter og dødstalismanene
# 7  2012111406120  Rowling, J.K.  2011       Harry Potter og Føniksordenen
# 8  2014080508099  Rowling, J.K.  2011                        Harry Potter
#
#                     4                                           5        6  \
# 0                                                   Cappelen Damm    novel
# 1                                                   Cappelen Damm    novel
# 2                                        Damm;[Oslo] : Damm, 2001  fiction
# 3                                                   Cappelen Damm    novel
# 4                                                   Cappelen Damm    novel
# 5                                                   Cappelen Damm    novel
# 6                                                   Cappelen Damm    novel
# 7                                                   Cappelen Damm    novel
# 8  hele serien samlet  Cappelen Damm;[Oslo] : Cappelen Damm, 2011    novel
#
#                                   7    8    9
# 0  24bd005bcf6807078a3a47a3be9317a2  nob  eng
# 1  3de05e64425e462084ed2f09c41a0770  nob  eng
# 2  2fe2aa721da5a92a149e3f77d6bcf923  nob
# 3  1c3360806d1422c7aad420a3d6dbc35e  nob  eng
# 4  5274465ec80af9381bdbf35fc9b5c24f  nob  eng
# 5  b824979b383aab196ce6bb820d0edfc5  nob  eng
# 6  4f2d092d5e8188ff421d7b806e9fa22f  nob  eng
# 7  63a1be63c5824b6b0e9121f609c75c3f  nob  eng
# 8  f787bb39d6ae1b4821d4c064d6fd7d9a  nob  eng

# %% [markdown]
# Ser ut som alt ligger i siste bok, som inneholder hele serien. Men bør sjekke om alt er der. For øyblikket får det holde.

# %%
whole_series = [2014022806023,2013072208063,2014073005084,2014022605057,2014030406051,2012111406120]

# %%
whole_freq = nb.aggregate_urns(whole_series)

# %%
korpus_freq = nb.frame(whole_freq, 'korpus')

# %%
tot_korp = pd.concat([tot, nb.frame(whole_freq)], axis=1, sort=False).fillna(0)

# %%
tot_korp.loc['Grang']
# Out:
# tot      0.0
# 0      121.0
# Name: Grang, dtype: float64

# %%
total = nb.frame(tot_korp.fillna(0).mean(axis=1), 'tot')

# %%
total.loc['Grang']
# Out:
# tot    60.5
# Name: Grang, dtype: float64

# %%
characters = "Hermine Harry Ronny Malfang Krabbe Slur Humlesnurr Gygrid".split()

# %%
coll = dict()
for word in characters:
    coll[word] = nb.urn_coll(word, whole_series,after=3, before=0)

# %%
for w in coll:
    coll[w].columns = [w]

# %%
coll_matrix = pd.concat([coll[w] for w in coll], axis=1, sort=False)

# %%
coll_matrix.head()
# Out:
#        Hermine   Harry   Ronny  Malfang  Krabbe   Slur  Humlesnurr  Gygrid
# .       1162.0  3166.0  1332.0    230.0    25.0  317.0       720.0   408.0
# «        853.0   354.0   907.0    128.0     2.0  182.0       504.0   270.0
# ,        685.0  2391.0   856.0    260.0    45.0  244.0       389.0   341.0
# og       551.0  1405.0  1220.0    160.0   150.0  152.0       274.0   207.0
# hadde    186.0   571.0   182.0     67.0     6.0   89.0       103.0    67.0

# %%
nb.frame_sort(nb.frame(coll_matrix['Hermine']**1.5/korpus_freq['korpus'])).head(20)
# Out:
#                            0
# Grang               2.662940
# insisterende        1.414214
# kjeklet             1.414214
# åndeløst            1.054093
# Kjempemorsomme      1.000000
# fornøyd.            1.000000
# Mobiliflorabus      1.000000
# forpustet           1.000000
# skråsikkert         1.000000
# Namnet              1.000000
# kutteflikene        1.000000
# skliende            1.000000
# tildekkede          1.000000
# tilfredsstillende.  1.000000
# gullbegeret         1.000000
# togende             1.000000
# inntrengende;       1.000000
# Lynglimtet          1.000000
# skingrendeogsa      1.000000
# innfløkt            1.000000

# %%
sky = nb.frame_sort(nb.frame(coll_matrix['Hermine']/tot['tot'])).head(20)
nb.cloud(sky)

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

# %%
select_form('rødt')
# Out:
# 'subst'

# %%
nb.word_form('spiste')
# Out:
# ['adj <perf-part> be ent <intrans1> <trans1> <trans11/opp> <trans11/på> <predik6> <refl9/innpå> <trans4> <part3/i> normert',
#  'adj <perf-part> fl <intrans1> <trans1> <trans11/opp> <trans11/på> <predik6> <refl9/innpå> <trans4> <part3/i> normert',
#  'verb pret <intrans1> <trans1> <trans11/opp> <trans11/på> <predik6> <refl9/innpå> <trans4> <part3/i> normert']

# %%
nb.word_lemma('spiste')
# Out:
# [['adj', 'spise'], ['verb', 'spise']]

# %%
character_words('Harry')
# Out:
# {'subst': ['kjensel', 'bykset', 'dagboka', 'ettertrykk', 'kappen'],
#  'unknown': ['bråsnudde', 'halvkvalt', 'characters', 'bråstoppet'],
#  'verb': ['glodde',
#   'måpte',
#   'overhørte',
#   'glante',
#   'pot',
#   'bøy',
#   'gapte',
#   'myste',
#   'kikket',
#   'snurret',
#   'flirte',
#   'forbløffet',
#   'skottet',
#   'bløff',
#   'overrumplet',
#   'enset',
#   'braste',
#   'potter',
#   'avskydde',
#   'gjengjeldte',
#   'hult'],
#  'adj': ['indignert',
#   'målløs',
#   'bistert',
#   'fortumlet',
#   'desperat',
#   'forlegent',
#   'innbitt',
#   'dystert',
#   'barskt',
#   'bittert',
#   'nervøst',
#   'mistenksomt',
#   'ekkel']}

# %%
cw = dict()
for w in characters:
    cw[w] = character_words(w)

# %%
text = ""
for ch in cw:
    #print(ch)
    innertext = ""
    for cat in cw[ch]:
        words = ', '.join([w for w in cw[ch][cat]])
        innertext += "\n## " + cat + "\n" + words
    #print(ch, words)
    text += "\n# "+ ch + "\n" + innertext
mu.printmd(text)
# Out:
# # Hermine
#
# ## adj
# spisst, barskt, beklemt, skingrende, indignert, oppspilt, bistert, nervøst, lyserød, forskende, bestyrtet, åndsfraværende, overlegent, utålmodig, uanfektet, stillferdig, nølende, anklagende, sarkastisk, innbitt, tankefullt, knusende, advarende
# ## verb
# overhørte, skottet, vekslet, smekket, sjokkert, himlet, klynket, overrumplet, glante, forskrekket, hæl, anspent, strålte, skummet, vettskremt, begravde, reparerte
# ## subst
# øyebrynene, bommen, tallerkenene
# ## unknown
# godnatt, bråstoppet, halvkvalt
# # Harry
#
# ## subst
# kjensel, bykset, dagboka, ettertrykk, kappen
# ## unknown
# bråsnudde, halvkvalt, characters, bråstoppet
# ## verb
# glodde, måpte, overhørte, glante, pot, bøy, gapte, myste, kikket, snurret, flirte, forbløffet, skottet, bløff, overrumplet, enset, braste, potter, avskydde, gjengjeldte, hult
# ## adj
# indignert, målløs, bistert, fortumlet, desperat, forlegent, innbitt, dystert, barskt, bittert, nervøst, mistenksomt, ekkel
# # Ronny
#
# ## verb
# glodde, måpte, himlet, skottet, skulte, dultet, gliste, vekslet, stappet, lusket, snappet, trev, snurret, gapte, flirte, snøftet, fniste, snorket
# ## adj
# storøyd, grettent, indignert, dystert, lengselsfullt, sarkastisk, lyserød, sammenbitte, nervøst, fortumlet, distré, åndsfraværende, advarende, innbitt, utydelig, bitende
# ## subst
# bykset, vantro, tulling, baksida, timeplanen, munnfull
# ## unknown
# bråstoppet, oversa, halvkvalt
# # Malfang
#
# ## adj
# slepende, hånlig, blekere, ondskapsfullt, sammenbitt, grettent, hardhendt, vemmelig, seilende, farende, spottende, sarkastisk
# ## subst
# fersken, dagboka, overarmen, vemmelse, arrest
# ## verb
# måpte, snurret, sladret, forsømme, skygget, fniste, frikjent, åpna, forvridd, kruset, vedder, virka, brygger, smette, brøle, sjanglet, klorte, slentret, peste, svulmet
# ## unknown
# bråstoppet, ors, hvertfall
# ## prep
# herover
# ## interj
# hæ
# ## adv
# forhåpentlig
# # Krabbe
#
# ## verb
# tuslet, fniste, ravet, klukket, begravde, flirte, glefset, snurret, utstøtte, løsne, rygget, hakk, stjal, glodde, snublet, hylte, stivnet, smelte, akter, brølte, begeistret, spilte, pekte, dukket, levde, holder, trengte, sto, åpnet, lo, ropte, fulgte
# ## adv
# øyensynlig, tydeligvis
# ## adj
# ulovlige, stygt, høyeste
# ## det
# halvannen
# ## subst
# kappen, sti, halsen, munnen, meter
# ## prep
# framover, nede
# # Slur
#
# ## unknown
# oversa, gjøra, bråstoppet
# ## subst
# staven, advarselen, innsida, forbannelser, fella, hælen, panikken, forvarsel, overlærer, tinningen
# ## adj
# ondskapsfullt, dovent, svevende, nifst, hånlig, ugjenkallelig, feiende, blekere, sammenbitte, ettertrykkelig, spottende, motstrebende, illevarslende
# ## verb
# provosere, avskydde, ilegge, bløtt, frikjent, overdøvet, lusket, kolliderte, forhekset, ombestemme, mønstret, mislikte, tørret, enset, sjanglet, skreket, snappet, haltet
# # Humlesnurr
#
# ## adj
# stillferdig, elskverdig, granskende, lavmælt, senil, vurderende, rungende, blidt, unnskyldende, høflig, forrest
# ## verb
# overhørte, forhekset, gjennomskuet, huket, kremtet, gjennomskue, nynnet, motarbeidet, spådd, bøy, advart, klin, sirklet, låser, vrøvl, suspendert, insistere, dirigerte, måpte, utstrålte, befalt, begraves
# ## unknown
# vars, oversa, ors, morra
# ## subst
# øyebrynene, tampen, tulling, trollmannen, trollmann, bøtta, sølvet
# # Gygrid
#
# ## verb
# tørret, klasket, trev, brøle, peste, kamuflert, utvist, tute, hvelv, skulte, skjelle, gjespet, viftet
# ## adj
# barskt, hemmelighetsfullt, sørgmodig, indignert, egenhendig, ekstatisk, grettent, likeglad, lojalt, tillitsfullt, rungende, bønnfallende, urettmessig, makelig, dundrende, vaktsomt, kolossalt, patetisk
# ## unknown
# halvkvalt, bråsnudde, overvaket
# ## subst
# sparken, madame, tulling, baksida, selvtilliten, tommel, bykset, gjenkomst, paraplyen
# ## interj
# hæ

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Harry']/tot['tot'], 'association')).head(20).index))
# Out:
# ['Ronny', 'Hermine', 'Potter', 'kjensel', 'bråsnudde', 'glodde', 'måpte', 'Harry', 'overhørte', 'glante', 'indignert', 'Assen', 'målløs', 'pot', 'Perry', 'bøy', 'bistert', 'gapte', 'fortumlet', 'myste']

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Hermine']/tot['tot'], 'association')).head(20).index))
# Out:
# ['Ronny', 'Hermine', 'spisst', 'barskt', 'beklemt', 'Harry', 'skingrende', 'indignert', 'oppspilt', 'overhørte', 'bistert', 'skottet', 'nervøst', 'lyserød', 'øyebrynene', 'forskende', 'vekslet', 'godnatt', 'bestyrtet', 'bommen']

# %%
res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix['Ronny']/tot['tot'], 'association')).head(50).index))['other']}
result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
print(result)
# Out:
# {'verb': ['glodde', 'måpte', 'himlet', 'skottet', 'skulte', 'dultet', 'gliste', 'vekslet', 'stappet', 'lusket', 'snappet', 'trev', 'snurret', 'gapte', 'flirte', 'snøftet', 'fniste', 'snorket'], 'adj': ['storøyd', 'grettent', 'indignert', 'dystert', 'lengselsfullt', 'sarkastisk', 'lyserød', 'sammenbitte', 'nervøst', 'fortumlet', 'distré', 'åndsfraværende', 'advarende', 'innbitt', 'utydelig', 'bitende'], 'subst': ['bykset', 'vantro', 'tulling', 'baksida', 'timeplanen', 'munnfull'], 'unknown': ['bråstoppet', 'oversa', 'halvkvalt']}

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Malfang']/tot['tot'], 'association')).head(20).index))
# Out:
# ['Krabbe', 'slepende', 'hånlig', 'Hermine', 'fersken', 'blekere', 'måpte', 'bråstoppet', 'dagboka', 'ondskapsfullt', 'snurret', 'Ronny', 'Harry', 'sladret', 'herover', 'forsømme', 'ors', 'overarmen', 'sammenbitt', 'grettent']

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Humlesnurr']/tot['tot'], 'association')).head(20).index))
# Out:
# ['stillferdig', 'Harry', 'overhørte', 'Ronny', 'vars', 'Potter', 'elskverdig', 'granskende', 'forhekset', 'gjennomskuet', 'øyebrynene', 'lavmælt', 'huket', 'kremtet', 'gjennomskue', 'senil', 'oversa', 'nynnet', 'tampen', 'motarbeidet']

# %%
print(list(nb.frame_sort(nb.frame(coll_matrix['Slur']/tot['tot'], 'association')).head(20).index))
# Out:
# ['oversa', 'staven', 'ondskapsfullt', 'Potter', 'Harry', 'dovent', 'provosere', 'svevende', 'nifst', 'avskydde', 'ilegge', 'advarselen', 'hånlig', 'bløtt', 'innsida', 'forbannelser', 'ugjenkallelig', 'frikjent', 'fella', 'feiende']

# %%
merge_coll = pd.concat([nb.frame(coll_matrix[w]/tot['tot'], w) for w in coll_matrix], axis=1, sort=False)

# %%
merge_coll.head()
# Out:
#         Hermine         Harry         Ronny       Malfang        Krabbe  \
# !  6.918621e-07  5.534897e-06  1.272134e-06  2.678176e-07  2.231813e-08
# "           NaN  1.748135e-08  1.748135e-08           NaN           NaN
# #  6.667835e-06  1.030484e-05  9.092502e-06  1.212334e-06           NaN
# $           NaN           NaN           NaN           NaN           NaN
# %           NaN           NaN           NaN           NaN           NaN
#
#            Slur  Humlesnurr        Gygrid
# !  3.124539e-07    0.000001  9.596797e-07
# "           NaN         NaN           NaN
# #  6.061668e-07    0.000001  1.212334e-06
# $           NaN         NaN  5.051541e-07
# %           NaN         NaN           NaN

# %%
nb.heatmap(nb.frame(merge_coll.loc["syk dårlig føler følte sa sier mente mener hevdet hevder løy ond ondskapsfullt".split()]))
# Out:
# <style  type="text/css" >
#     #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row0_col6 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row0_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row1_col1 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row1_col3 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row1_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row1_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row2_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row2_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row3_col0 {
#             background-color:  #50ac50;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row3_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row3_col2 {
#             background-color:  #85ca85;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row3_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row3_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row3_col6 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row3_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row4_col1 {
#             background-color:  #aadeaa;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row4_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row4_col3 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row4_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row4_col5 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row4_col6 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row4_col7 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row5_col0 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row5_col2 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row5_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row5_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row5_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row5_col6 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row5_col7 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row6_col0 {
#             background-color:  #98d498;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row6_col1 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row6_col2 {
#             background-color:  #3da23d;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row6_col3 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row6_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row6_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row6_col6 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row6_col7 {
#             background-color:  #7fc67f;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row7_col0 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row7_col1 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row7_col2 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_ff12a46e_e308_11e9_a444_a0a4c554f2a3row7_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;

# %%
nb.heatmap(nb.frame_sort(merge_coll, 'Harry')[:20])
# Out:
# <style  type="text/css" >
#     #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row0_col2 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row0_col3 {
#             background-color:  #77c277;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row0_col5 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row0_col6 {
#             background-color:  #4eab4e;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row0_col7 {
#             background-color:  #77c277;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row1_col0 {
#             background-color:  #9fd89f;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row1_col1 {
#             background-color:  #46a746;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row1_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row1_col5 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row1_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row1_col7 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row2_col1 {
#             background-color:  #5ab25a;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row2_col3 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row2_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row2_col6 {
#             background-color:  #5bb25b;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row2_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row3_col1 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row3_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row3_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row3_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row3_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row4_col1 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row4_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row4_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row4_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row4_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row4_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row4_col7 {
#             background-color:  #a7dda7;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row5_col0 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row5_col1 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row5_col2 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row5_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row5_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row5_col5 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row5_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row5_col7 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row6_col0 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row6_col1 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row6_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row6_col3 {
#             background-color:  #42a442;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row6_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row6_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row6_col6 {
#             background-color:  #a3daa3;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row6_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row7_col0 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row7_col1 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row7_col2 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_4f21d266_e2f9_11e9_add8_a0a4c554f2a3row7_col3 {
#             background-color:  #77c277;
#             color:  #000000;

# %%
cosinus = nb.frame(matrix_cosine(merge_coll, top=300))

# %%
nb.heatmap(nb.frame_sort(cosinus, 'Krabbe'))
# Out:
# <style  type="text/css" >
#     #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row0_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row0_col5 {
#             background-color:  #0b860b;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row0_col6 {
#             background-color:  #1e901e;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row0_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row1_col0 {
#             background-color:  #a8dda8;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row1_col1 {
#             background-color:  #76c176;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row1_col2 {
#             background-color:  #a3daa3;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row1_col3 {
#             background-color:  #75c175;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row1_col4 {
#             background-color:  #088408;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row1_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row1_col6 {
#             background-color:  #058305;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row1_col7 {
#             background-color:  #9fd89f;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row2_col0 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row2_col1 {
#             background-color:  #4aa94a;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row2_col2 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row2_col3 {
#             background-color:  #5ab25a;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row2_col4 {
#             background-color:  #138a13;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row2_col5 {
#             background-color:  #058205;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row2_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row2_col7 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row3_col0 {
#             background-color:  #349d34;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row3_col1 {
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row3_col2 {
#             background-color:  #2b982b;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row3_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row3_col4 {
#             background-color:  #51ad51;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row3_col5 {
#             background-color:  #399f39;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row3_col6 {
#             background-color:  #319b31;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row3_col7 {
#             background-color:  #43a543;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row4_col0 {
#             background-color:  #3da23d;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row4_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row4_col2 {
#             background-color:  #339c33;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row4_col3 {
#             background-color:  #128a12;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row4_col4 {
#             background-color:  #54ae54;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row4_col5 {
#             background-color:  #3aa03a;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row4_col6 {
#             background-color:  #2a972a;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row4_col7 {
#             background-color:  #2b982b;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row5_col0 {
#             background-color:  #399f39;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row5_col1 {
#             background-color:  #56af56;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row5_col2 {
#             background-color:  #369e36;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row5_col3 {
#             background-color:  #89cc89;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row5_col4 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row5_col5 {
#             background-color:  #9ed79e;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row5_col6 {
#             background-color:  #87cb87;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row5_col7 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row6_col0 {
#             background-color:  #018001;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row6_col1 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row6_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row6_col3 {
#             background-color:  #6cbc6c;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row6_col4 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row6_col5 {
#             background-color:  #c5edc5;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row6_col6 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row6_col7 {
#             background-color:  #43a543;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row7_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row7_col1 {
#             background-color:  #a7dda7;
#             color:  #000000;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row7_col2 {
#             background-color:  #018001;
#             color:  #f1f1f1;
#         }    #T_c95210b6_e2fc_11e9_889b_a0a4c554f2a3row7_col3 {
#             background-color:  #94d294;
#             color:  #000000;

# %%
import networkx as nx

# %%
import dhlab.graph_networkx_louvain as gnl

# %%
G = nx.from_pandas_adjacency(cosinus)

# %%
gnl.show_graph(G)
# Out:
# C:\Users\larsj\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
gnl.show_communities(G)
# Out:
# Gygrid :  Gygrid
#
# Harry :  Harry
#
# Hermine-Ronny :  Hermine, Ronny
#
# Humlesnurr-Slur :  Humlesnurr, Slur, Krabbe
#
# Malfang :  Malfang

# %%
nb.urn_concordance(word = "fortumlet", urns = whole_series, size=20)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014022806023?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og de vises stein, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>Men Nilus - nervøs ,</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>og redd for å bli</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014022806023?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og de vises stein, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>Kvist ? tenkte Harry</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>. Var det en stokk</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014022806023?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og de vises stein, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>slapp han kvelertaket og stirret</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>på handflatene - Harry kunne</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072208063?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og fangen fra Azkaban, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>med deg ! » Totalt</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>stirret Harry på bålet .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072208063?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og fangen fra Azkaban, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>, og stemmen lød like</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>som imponert .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072208063?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og fangen fra Azkaban, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>. Harry hadde bare et</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>inntrykk av larm og kropper</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072208063?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og fangen fra Azkaban, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>av ham . Harry prøvde</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>å reise seg ; det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072208063?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og fangen fra Azkaban, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>Hermine . Ronny så like</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>ut som ham seiv og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072208063?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og fangen fra Azkaban, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>venn ... han var helt</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>... Hva kom til å</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013072208063?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og fangen fra Azkaban, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>åpne hoveddørene . Han så</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>på Hermine , og på</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073005084?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og ildbegeret, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>like</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>som irene over den brå</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073005084?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og ildbegeret, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>nærhet ! » pep hun</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>og la seg framover for</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073005084?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og ildbegeret, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>koffertene hadde gjort ham aldeles</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073005084?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og ildbegeret, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>oppfatta ? » sa Ronny</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>. « Harry - hva</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073005084?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og ildbegeret, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>. Jenta så redd og</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>ut , men Ronny bare</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073005084?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og ildbegeret, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>var over , tenkte Harry</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>, mens madam Pomfrit begynte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073005084?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og ildbegeret, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>? » spurte han Ronny</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073005084?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og ildbegeret, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>tung slegge . Han blunket</td>
#                 <td>fortumlet</td>
#                 <td style='text-align:left'>og stirret på Humlesnurr med</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014022605057?searchText=fortumlet' target='_blank' style='text-decoration:none'>Harry Potter og halvblodsprinsen, Rowling, J.K., 2011</a>
#                 </td>
#                 <td>Nilus ble lys
